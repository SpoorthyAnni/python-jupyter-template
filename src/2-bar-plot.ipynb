# %% [markdown]
# ### Exercise 2: Bar Plot with Colors

# %%
# TASK: Create a bar plot with the following data: categories = ['A', 'B', 'C', 'D'] and values = [5, 7, 3, 9].
# Use different colors for each bar and add a title to the plot.

import matplotlib.pyplot as plt
import seaborn as sns

categories = ['A', 'B', 'C', 'D']
values = [5, 7, 3, 9]

# Generate a color palette dynamically
colors = sns.color_palette("husl", len(categories))  # "husl" ensures distinct, visually appealing colors

# Error handling
if len(categories) != len(values):
    raise ValueError("categories and values must have the same length")

plt.figure(figsize=(6, 4))
plt.bar(categories, values, color=colors)

# Customizations
plt.title('Bar Plot of Categories', fontsize=14)
plt.xlabel('Categories', fontsize=12)
plt.ylabel('Values', fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.6)

plt.show()

# %%
pip install seaborn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 1.9 MB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 29.5 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.9/507.9 kB 42.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 346.8/346.8 kB 37.3 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 23.0.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
